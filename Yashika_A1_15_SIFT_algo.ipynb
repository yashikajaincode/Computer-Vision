# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_path = 'sift1.jpg'
image = cv2.imread(image_path)

if image is None:
    print("Error: Unable to load image!")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    # SIFT Feature Detection
    sift = cv2.SIFT_create()
    keypoints_sift = sift.detect(gray, None)

    # Draw keypoints
    sift_image = cv2.drawKeypoints(image_rgb, keypoints_sift, None, (0,255,0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

    # Display
    plt.figure(figsize=(5, 5))
    plt.imshow(sift_image)
    plt.title("SIFT Keypoints")
    plt.axis("off")
    plt.show()

# %%
#Clock tower from different angle 
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_path = 'sift2.jpg'
image = cv2.imread(image_path)

if image is None:
    print("Error: Unable to load image!")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    # SIFT Feature Detection
    sift = cv2.SIFT_create()
    keypoints_sift = sift.detect(gray, None)

    # Draw keypoints
    sift_image = cv2.drawKeypoints(image_rgb, keypoints_sift, None, (0,255,0), flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

    # Display
    plt.figure(figsize=(5, 5))
    plt.imshow(sift_image)
    plt.title("SIFT Keypoints")
    plt.axis("off")
    plt.show()
